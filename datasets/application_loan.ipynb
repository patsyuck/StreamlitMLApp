# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('application_train.csv')
data.tail()
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 307506      456251       0         Cash loans           M            N
# 307507      456252       0         Cash loans           F            N
# 307508      456253       0         Cash loans           F            N
# 307509      456254       1         Cash loans           F            N
# 307510      456255       0         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 307506               N             0          157500.0    254700.0
# 307507               Y             0           72000.0    269550.0
# 307508               Y             0          153000.0    677664.0
# 307509               Y             0          171000.0    370107.0
# 307510               N             0          157500.0    675000.0
#
#         AMT_ANNUITY  ...  FLAG_DOCUMENT_18 FLAG_DOCUMENT_19 FLAG_DOCUMENT_20  \
# ...

# %%
data.TARGET.value_counts()
# Out:
# 0    282686
# 1     24825
# Name: TARGET, dtype: int64

# %%
data.CODE_GENDER.value_counts()
# Out:
# F      202448
# M      105059
# XNA         4
# Name: CODE_GENDER, dtype: int64

# %%
data.FLAG_OWN_CAR.value_counts()
# Out:
# N    202924
# Y    104587
# Name: FLAG_OWN_CAR, dtype: int64

# %%
data.FLAG_OWN_REALTY.value_counts()
# Out:
# Y    213312
# N     94199
# Name: FLAG_OWN_REALTY, dtype: int64

# %%
data.CNT_CHILDREN.value_counts()
# Out:
# 0     215371
# 1      61119
# 2      26749
# 3       3717
# 4        429
# 5         84
# 6         21
# 7          7
# 14         3
# 8          2
# 9          2
# 12         2
# 10         2
# 19         2
# 11         1
# Name: CNT_CHILDREN, dtype: int64

# %%
data[data['CNT_CHILDREN'] > 9]
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 34545       140032       1         Cash loans           M            Y
# 80948       193853       0         Cash loans           F            N
# 132585      253779       0         Cash loans           F            N
# 155369      280108       0         Cash loans           F            N
# 171125      298322       0    Revolving loans           F            N
# 176011      303956       0         Cash loans           M            Y
# 183878      313127       0         Cash loans           F            Y
# 186820      316580       0         Cash loans           F            N
# 265784      407877       0         Cash loans           F            N
# 267998      410527       0         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 34545                N            11          315000.0   1007761.5
# ...

# %%
plt.hist(data['AMT_INCOME_TOTAL']/1000, bins=range(0, 1001, 50));

# %%
min(data['AMT_INCOME_TOTAL']), max(data['AMT_INCOME_TOTAL'])
# Out:
# (25650.0, 117000000.0)

# %%
plt.hist(data['AMT_ANNUITY']/1000, bins=range(0, 101, 10));

# %%
min(data['AMT_ANNUITY']), max(data['AMT_ANNUITY'])
# Out:
# (1615.5, 258025.5)

# %%
plt.hist(data['AMT_INCOME_TOTAL']/1000, bins=range(0, 1001, 50));

# %%
min(data['AMT_CREDIT']), max(data['AMT_CREDIT'])
# Out:
# (45000.0, 4050000.0)

# %%
plt.hist(data['AMT_GOODS_PRICE']/1000, bins=range(0, 2001, 200));

# %%
min(data['AMT_GOODS_PRICE']), max(data['AMT_GOODS_PRICE'])
# Out:
# (40500.0, 4050000.0)

# %%
data.NAME_INCOME_TYPE.value_counts()
# Out:
# Working                 158774
# Commercial associate     71617
# Pensioner                55362
# State servant            21703
# Unemployed                  22
# Student                     18
# Businessman                 10
# Maternity leave              5
# Name: NAME_INCOME_TYPE, dtype: int64

# %%
data.NAME_EDUCATION_TYPE.value_counts()
# Out:
# Secondary / secondary special    218391
# Higher education                  74863
# Incomplete higher                 10277
# Lower secondary                    3816
# Academic degree                     164
# Name: NAME_EDUCATION_TYPE, dtype: int64

# %%
data.NAME_FAMILY_STATUS.value_counts()
# Out:
# Married                 196432
# Single / not married     45444
# Civil marriage           29775
# Separated                19770
# Widow                    16088
# Unknown                      2
# Name: NAME_FAMILY_STATUS, dtype: int64

# %%
data.NAME_HOUSING_TYPE.value_counts()
# Out:
# House / apartment      272868
# With parents            14840
# Municipal apartment     11183
# Rented apartment         4881
# Office apartment         2617
# Co-op apartment          1122
# Name: NAME_HOUSING_TYPE, dtype: int64

# %%
min(data.DAYS_BIRTH), max(data.DAYS_BIRTH)
# Out:
# (-25229, -7489)

# %%
df = data[['TARGET', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 
           'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_INCOME_TYPE', 
           'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH']]
df.tail()
# Out:
#         TARGET CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 307506       0           M            N               N             0
# 307507       0           F            N               Y             0
# 307508       0           F            N               Y             0
# 307509       1           F            N               Y             0
# 307510       0           F            N               N             0
#
#         AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 307506          157500.0    254700.0      27558.0         225000.0
# 307507           72000.0    269550.0      12001.5         225000.0
# 307508          153000.0    677664.0      29979.0         585000.0
# 307509          171000.0    370107.0      20205.0         319500.0
# 307510          157500.0    675000.0      49117.5         675000.0
#
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 307506               Working  Secondary / secondary special
# ...

# %%
df = df.rename(columns={'TARGET': 'target', 'CODE_GENDER': 'gender', 'FLAG_OWN_CAR': 'hasCar', 'FLAG_OWN_REALTY': 'hasRealty', 
        'CNT_CHILDREN': 'cntChildren', 'AMT_INCOME_TOTAL': 'income', 'AMT_CREDIT': 'credit', 'AMT_ANNUITY': 'annuity', 
        'AMT_GOODS_PRICE': 'goodsPrice', 'NAME_INCOME_TYPE': 'incomeType', 'NAME_EDUCATION_TYPE': 'education', 
        'NAME_FAMILY_STATUS': 'family', 'NAME_HOUSING_TYPE': 'apartment', 'DAYS_BIRTH': 'birth'})
df.tail()
# Out:
#         target gender hasCar hasRealty  cntChildren    income    credit  \
# 307506       0      M      N         N            0  157500.0  254700.0
# 307507       0      F      N         Y            0   72000.0  269550.0
# 307508       0      F      N         Y            0  153000.0  677664.0
# 307509       1      F      N         Y            0  171000.0  370107.0
# 307510       0      F      N         N            0  157500.0  675000.0
#
#         annuity  goodsPrice            incomeType  \
# 307506  27558.0    225000.0               Working
# 307507  12001.5    225000.0             Pensioner
# 307508  29979.0    585000.0               Working
# 307509  20205.0    319500.0  Commercial associate
# 307510  49117.5    675000.0  Commercial associate
#
#                             education     family          apartment  birth
# 307506  Secondary / secondary special  Separated       With parents  -9327
# 307507  Secondary / secondary special      Widow  House / apartment -20775
# ...

# %%
df.loc[:, 'gender'] = df['gender'].apply(lambda x: 0 if x == 'F' else (1 if x == 'M' else np.nan))
df.loc[:, 'hasCar'] = df['hasCar'].apply(lambda x: 0 if x == 'N' else 1)
df.loc[:, 'hasRealty'] = df['hasRealty'].apply(lambda x: 0 if x == 'N' else 1)
df.loc[:, 'cntChildren'] = df['cntChildren'].apply(lambda x: x if x < 6 else 6)
df.loc[:, 'income'] = df['income'].apply(lambda x: x // 50000 if x < 500000 else 10)
df.loc[:, 'credit'] = df['credit'].apply(lambda x: x // 50000 if x < 500000 else 10)
df.loc[:, 'annuity'] = df['annuity'].apply(lambda x: x // 10000 if x < 100000 else 10)
df.loc[:, 'goodsPrice'] = df['goodsPrice'].apply(lambda x: x // 200000 if x < 2000000 else 10)
df.loc[:, 'IsJobWorking'] = df['incomeType'].apply(lambda x: 1 if x == 'Working' else 0)
df.loc[:, 'IsJobCommercial'] = df['incomeType'].apply(lambda x: 1 if x == 'Commercial associate' else 0)
df.loc[:, 'IsJobState'] = df['incomeType'].apply(lambda x: 1 if x == 'State servant' else 0)
df.loc[:, 'IsJobPensioner'] = df['incomeType'].apply(lambda x: 1 if x == 'Pensioner' else 0)
df.loc[:, 'IsEducLowerSec'] = df['education'].apply(lambda x: 1 if x == 'Lower secondary' else 0)
df.loc[:, 'IsEducSecondary'] = df['education'].apply(lambda x: 1 if x == 'Secondary / secondary special' else 0)
df.loc[:, 'IsEducHigherInc'] = df['education'].apply(lambda x: 1 if x == 'Incomplete higher' else 0)
df.loc[:, 'IsEducHigher'] = df['education'].apply(lambda x: 1 if x == 'Higher education' else 0)
df.loc[:, 'IsFamMarried'] = df['family'].apply(lambda x: 1 if x == 'Married' else 0)
df.loc[:, 'IsFamNotMarried'] = df['family'].apply(lambda x: 1 if x == 'Single / not married' else 0)
df.loc[:, 'IsFamCivil'] = df['family'].apply(lambda x: 1 if x == 'Civil marriage' else 0)
df.loc[:, 'IsFamSeparated'] = df['family'].apply(lambda x: 1 if x == 'Separated' else 0)
df.loc[:, 'IsFamWidow'] = df['family'].apply(lambda x: 1 if x == 'Widow' else 0)
df.loc[:, 'IsApartHouse'] = df['apartment'].apply(lambda x: 1 if x == 'House / apartment' else 0)
df.loc[:, 'IsApartParents'] = df['apartment'].apply(lambda x: 1 if x == 'With parents' else 0)
df.loc[:, 'IsApartMunicipal'] = df['apartment'].apply(lambda x: 1 if x == 'Municipal apartment' else 0)
df.loc[:, 'IsApartRented'] = df['apartment'].apply(lambda x: 1 if x == 'Rented apartment' else 0)
df.loc[:, 'IsApartOffice'] = df['apartment'].apply(lambda x: 1 if x == 'Office apartment' else 0)
df.loc[:, 'age'] = df['birth'].apply(lambda x: abs(x) // 365)
df.tail()
# Out:
#         target  gender  hasCar  hasRealty  cntChildren  income  credit  \
# 307506       0     1.0       0          0            0     3.0     5.0
# 307507       0     0.0       0          1            0     1.0     5.0
# 307508       0     0.0       0          1            0     3.0    10.0
# 307509       1     0.0       0          1            0     3.0     7.0
# 307510       0     0.0       0          0            0     3.0    10.0
#
#         annuity  goodsPrice            incomeType  ... IsFamNotMarried  \
# 307506      2.0         1.0               Working  ...               0
# 307507      1.0         1.0             Pensioner  ...               0
# 307508      2.0         2.0               Working  ...               0
# 307509      2.0         1.0  Commercial associate  ...               0
# 307510      4.0         3.0  Commercial associate  ...               0
#
#        IsFamCivil IsFamSeparated  IsFamWidow  IsApartHouse  IsApartParents  \
# ...

# %%
df = df.drop(['incomeType', 'education', 'family', 'apartment', 'birth'], axis=1)
df.tail()
# Out:
#         target  gender  hasCar  hasRealty  cntChildren  income  credit  \
# 307506       0     1.0       0          0            0     3.0     5.0
# 307507       0     0.0       0          1            0     1.0     5.0
# 307508       0     0.0       0          1            0     3.0    10.0
# 307509       1     0.0       0          1            0     3.0     7.0
# 307510       0     0.0       0          0            0     3.0    10.0
#
#         annuity  goodsPrice  IsJobWorking  ...  IsFamNotMarried  IsFamCivil  \
# 307506      2.0         1.0             1  ...                0           0
# 307507      1.0         1.0             0  ...                0           0
# 307508      2.0         2.0             1  ...                0           0
# 307509      2.0         1.0             0  ...                0           0
# 307510      4.0         3.0             0  ...                0           0
#
#         IsFamSeparated  IsFamWidow  IsApartHouse  IsApartParents  \
# ...

# %%
df.to_csv('loan_train.csv', index=False)
